# %%
from PIL import Image
from augment import white_balancer, rotator

image = Image.open("./test.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x480 at 0x10475BB00>

# %%
y = [balanced for balanced in white_balancer(image, 3, [1200, 20000])]
y[2]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x10475BF98>

# %%
y[0]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x10475BCF8>

# %%
x = [rotated for rotated in rotator(image, 4)]
x[3]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x104763128>

# %%
x[2]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x102BC8940>
