# %%
from PIL import Image
import numpy as np
from augment import augment

augmented_images = [i for i in augment(Image.open("./test.jpg"))]
for image in augmented_images:
    display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x1121AFB70>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F5C0>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F2E8>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F6A0>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F898>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F978>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0FA58>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0FB38>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0F668>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0FA20>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x112C0FC50>
