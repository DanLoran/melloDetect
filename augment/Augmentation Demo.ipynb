# %%
from PIL import Image
import numpy as np
from augment import augment

image = Image.open("./test.jpg")
augmented_images = [i for i in augment(image)]
display(augmented_images[0])
displa(augmented_images[1]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x1088ED320>
# <PIL.Image.Image image mode=RGB size=480x480 at 0x109E6B198>

# %%
y = [balanced for balanced in white_balancer(image, 3, [1900, 20000])]
y[2]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x104FCCD30>

# %%
y[0]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x104FCCB38>

# %%
x = [rotated for rotated in rotator(image, 4)]
x[3]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x104763128>

# %%
x[2]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x102BC8940>

# %%
z = [mirrored for mirrored in mirror(image)]
z[0]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x10498F160>

# %%
z[1]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x10553E358>

# %%
w = [a for a in noise(image, 2, 20)]
w[1]
# Out:
# <PIL.Image.Image image mode=RGB size=480x480 at 0x104FCC9B0>
